# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Financials.csv')

# %%
df.head()
# Out:
#       Segment  Country     Product   Discount Band   Units Sold   \
# 0  Government   Canada   Carretera            None    $1,618.50
# 1  Government  Germany   Carretera            None    $1,321.00
# 2   Midmarket   France   Carretera            None    $2,178.00
# 3   Midmarket  Germany   Carretera            None      $888.00
# 4   Midmarket   Mexico   Carretera            None    $2,470.00
#
#    Manufacturing Price   Sale Price   Gross Sales   Discounts         Sales   \
# 0                $3.00       $20.00    $32,370.00        $-      $32,370.00
# 1                $3.00       $20.00    $26,420.00        $-      $26,420.00
# 2                $3.00       $15.00    $32,670.00        $-      $32,670.00
# 3                $3.00       $15.00    $13,320.00        $-      $13,320.00
# 4                $3.00       $15.00    $37,050.00        $-      $37,050.00
#
#           COGS        Profit         Date  Month Number  Month Name   Year
# ...

# %%
df.columns
# Out:
# Index(['Segment', 'Country', ' Product ', ' Discount Band ', ' Units Sold ',
#        ' Manufacturing Price ', ' Sale Price ', ' Gross Sales ', ' Discounts ',
#        '  Sales ', ' COGS ', ' Profit ', 'Date', 'Month Number',
#        ' Month Name ', 'Year'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Segment                  0
# Country                  0
#  Product                 0
#  Discount Band           0
#  Units Sold              0
#  Manufacturing Price     0
#  Sale Price              0
#  Gross Sales             0
#  Discounts               0
#   Sales                  0
#  COGS                    0
#  Profit                  0
# Date                     0
# Month Number             0
#  Month Name              0
# Year                     0
# dtype: int64

# %%
df.describe()
# Out:
#        Month Number         Year
# count    700.000000   700.000000
# mean       7.900000  2013.750000
# std        3.377321     0.433322
# min        1.000000  2013.000000
# 25%        5.750000  2013.750000
# 50%        9.000000  2014.000000
# 75%       10.250000  2014.000000
# max       12.000000  2014.000000

# %%
df[' Discount Band '].value_counts()
# Out:
#  Discount Band
#  High       245
#  Medium     242
#  Low        160
#  None        53
# Name: count, dtype: int64

# %%
for col in df.columns:
  print(col)
  print(df[col].value_counts())
  print()
# Out:
# Segment
# Segment
# Government          300
# Midmarket           100
# Channel Partners    100
# Enterprise          100
# Small Business      100
# Name: count, dtype: int64
#
# Country
# Country
# Canada                      140
# Germany                     140
# France                      140
# Mexico                      140
# United States of America    140
# Name: count, dtype: int64
#
#  Product
#  Product
#  Paseo         202
#  Velo          109
#  VTT           109
#  Amarilla       94
#  Carretera      93
#  Montana        93
# Name: count, dtype: int64
#
#  Discount Band
#  Discount Band
#  High       245
#  Medium     242
#  Low        160
#  None        53
# Name: count, dtype: int64
#
#  Units Sold
#  Units Sold
#  $727.00       5
#  $2,844.00     4
#  $1,916.00     4
#  $663.00       4
#  $1,743.00     4
#               ..
#  $2,723.00     1
#  $1,460.00     1
#  $980.00       1
#  $887.00       1
#  $1,806.00     1
# Name: count, Length: 510, dtype: int64
#
# ...

# %% [markdown]
# Remove '$' sign and '-' from all columns

# %%
for col in df.columns:
  if df[col].dtype==object:
    df[col]=df[col].str.replace('[\$\-]',"",regex=True)

# %%
for col in df.columns:
  print(col)
  print(df[col].value_counts())
  print()
# Out:
# Segment
# Segment
# Government          300
# Midmarket           100
# Channel Partners    100
# Enterprise          100
# Small Business      100
# Name: count, dtype: int64
#
# Country
# Country
# Canada                      140
# Germany                     140
# France                      140
# Mexico                      140
# United States of America    140
# Name: count, dtype: int64
#
#  Product
#  Product
#  Paseo         202
#  Velo          109
#  VTT           109
#  Amarilla       94
#  Carretera      93
#  Montana        93
# Name: count, dtype: int64
#
#  Discount Band
#  Discount Band
#  High       245
#  Medium     242
#  Low        160
#  None        53
# Name: count, dtype: int64
#
#  Units Sold
#  Units Sold
#  727.00       5
#  2,844.00     4
#  1,916.00     4
#  663.00       4
#  1,743.00     4
#              ..
#  2,723.00     1
#  1,460.00     1
#  980.00       1
#  887.00       1
#  1,806.00     1
# Name: count, Length: 510, dtype: int64
#
# ...

# %%
# Verify if 'Profit' or a similar column exists
print(df.columns)

# If the column is present, proceed with the type conversion
if ' Month Name ' in df.columns:
    df[' Month Name '] = df[' Month Name '].astype('Int64', errors='ignore')
else:
    print("Column 'Profit' not found in the DataFrame.")
# Out:
# Index(['Segment', 'Country', ' Product ', ' Discount Band ', ' Units Sold ',
#        ' Manufacturing Price ', ' Sale Price ', ' Gross Sales ', ' Discounts ',
#        '  Sales ', ' COGS ', ' Profit ', 'Date', 'Month Number',
#        ' Month Name ', 'Year'],
#       dtype='object')

# %%
df[' Month Name '].dtypes
# Out:
# dtype('O')

# %%
df.head()
# Out:
#       Segment  Country     Product   Discount Band   Units Sold   \
# 0  Government   Canada   Carretera            None     1,618.50
# 1  Government  Germany   Carretera            None     1,321.00
# 2   Midmarket   France   Carretera            None     2,178.00
# 3   Midmarket  Germany   Carretera            None       888.00
# 4   Midmarket   Mexico   Carretera            None     2,470.00
#
#    Manufacturing Price   Sale Price   Gross Sales   Discounts        Sales   \
# 0                 3.00        20.00     32,370.00                32,370.00
# 1                 3.00        20.00     26,420.00                26,420.00
# 2                 3.00        15.00     32,670.00                32,670.00
# 3                 3.00        15.00     13,320.00                13,320.00
# 4                 3.00        15.00     37,050.00                37,050.00
#
#          COGS       Profit         Date  Month Number  Month Name   Year
# ...

# %%
# Remove commas from numerical columns
for col in df.select_dtypes(include=['object']):  # Select columns with object dtype
    df[col] = df[col].str.replace(',', '')

print(df)
# Out:
#               Segment                   Country     Product   Discount Band   \
# 0          Government                    Canada   Carretera            None
# 1          Government                   Germany   Carretera            None
# 2           Midmarket                    France   Carretera            None
# 3           Midmarket                   Germany   Carretera            None
# 4           Midmarket                    Mexico   Carretera            None
# ..                ...                       ...          ...             ...
# 695    Small Business                    France    Amarilla            High
# 696    Small Business                    Mexico    Amarilla            High
# 697        Government                    Mexico     Montana            High
# 698        Government                    Canada       Paseo            High
# 699  Channel Partners  United States of America         VTT            High
#
# ...

# %%
# Remove commas from numerical columns
for col in df.select_dtypes(include=['object']):  # Select columns with object dtype
    df[col] = df[col].str.replace(',', '')

print(df)
# Out:
#               Segment                   Country     Product   Discount Band   \
# 0          Government                    Canada   Carretera            None
# 1          Government                   Germany   Carretera            None
# 2           Midmarket                    France   Carretera            None
# 3           Midmarket                   Germany   Carretera            None
# 4           Midmarket                    Mexico   Carretera            None
# ..                ...                       ...          ...             ...
# 695    Small Business                    France    Amarilla            High
# 696    Small Business                    Mexico    Amarilla            High
# 697        Government                    Mexico     Montana            High
# 698        Government                    Canada       Paseo            High
# 699  Channel Partners  United States of America         VTT            High
#
# ...

# %%
# Choose the column you want to visualize
column_name = 'Segment'  # Replace with your actual column name

# Set up the figure
plt.figure(figsize=(12, 6))

# Plot 1: Histogram
plt.subplot(2, 1, 1)
sns.histplot(df[column_name], kde=True)  # kde=True adds a Kernel Density Estimate
plt.title(f'Histogram of {column_name}')

# Plot 2: Box plot
plt.subplot(2, 1, 2)
sns.boxplot(x=df[column_name])
plt.title(f'Box Plot of {column_name}')

# Show the plots
plt.tight_layout()
plt.show()

# %%
# Choose the column you want to visualize
column_name = 'Country'  # Replace with your actual column name

# Set up the figure
plt.figure(figsize=(12, 6))

# Plot 1: Histogram
plt.subplot(2, 1, 1)
sns.histplot(df[column_name], kde=True)  # kde=True adds a Kernel Density Estimate
plt.title(f'Histogram of {column_name}')

# Plot 2: Box plot
plt.subplot(2, 1, 2)
sns.boxplot(x=df[column_name])
plt.title(f'Box Plot of {column_name}')

# Show the plots
plt.tight_layout()
plt.show()

# %%
# Choose the column you want to visualize
column_name = 'Month Number'  # Replace with your actual column name

# Set up the figure
plt.figure(figsize=(12, 6))

# Plot 1: Histogram
plt.subplot(2, 1, 1)
sns.histplot(df[column_name], kde=True)  # kde=True adds a Kernel Density Estimate
plt.title(f'Histogram of {column_name}')

# Plot 2: Box plot
plt.subplot(2, 1, 2)
sns.boxplot(x=df[column_name])
plt.title(f'Box Plot of {column_name}')

# Show the plots
plt.tight_layout()
plt.show()

# %%
# Choose the column you want to visualize
column_name = ' Month Name '  # Replace with your actual column name

# Set up the figure
plt.figure(figsize=(12, 6))

# Plot 1: Histogram
plt.subplot(2, 1, 1)
sns.histplot(df[column_name], kde=True)  # kde=True adds a Kernel Density Estimate
plt.title(f'Histogram of {column_name}')

# Plot 2: Box plot
plt.subplot(2, 1, 2)
sns.boxplot(x=df[column_name])
plt.title(f'Box Plot of {column_name}')

# Show the plots
plt.tight_layout()
plt.show()

# %%
# Choose the column you want to visualize
column_name = 'Year'  # Replace with your actual column name

# Set up the figure
plt.figure(figsize=(12, 6))

# Plot 1: Histogram
plt.subplot(2, 1, 1)
sns.histplot(df[column_name], kde=True)  # kde=True adds a Kernel Density Estimate
plt.title(f'Histogram of {column_name}')

# Plot 2: Box plot
plt.subplot(2, 1, 2)
sns.boxplot(x=df[column_name])
plt.title(f'Box Plot of {column_name}')

# Show the plots
plt.tight_layout()
plt.show()

# %%
# Choose the column you want to visualize
column_name = 'Date'  # Replace with your actual column name

# Set up the figure
plt.figure(figsize=(16, 7))

# Plot 1: Histogram
plt.subplot(5, 1, 1)
sns.histplot(df[column_name], kde=True)  # kde=True adds a Kernel Density Estimate
plt.title(f'Histogram of {column_name}')

# Plot 2: Box plot
plt.subplot(5, 1, 2)
sns.boxplot(x=df[column_name])
plt.title(f'Box Plot of {column_name}')

# Show the plots
plt.tight_layout()
plt.show()
